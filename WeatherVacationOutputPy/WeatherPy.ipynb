# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    weather_api_key = "9ee92eba9a706c55ea1fa3afd7e8b3b4"
    
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | san marcos de colon
# Processing Record 3 of Set 1 | cuamba
# Processing Record 4 of Set 1 | leh
# Processing Record 5 of Set 1 | constantia
# Processing Record 6 of Set 1 | puerto natales
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | tokar
# Processing Record 9 of Set 1 | okhotsk
# Processing Record 10 of Set 1 | puerto la cruz
# Processing Record 11 of Set 1 | codrington
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | cannonvale
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | siwa oasis
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | santiago de cao
# Processing Record 19 of Set 1 | cassilandia
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | hadibu
# Processing Record 23 of Set 1 | west island
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | olonkinbyen
# Processing Record 26 of Set 1 | nuuk
# Processing Record 27 of Set 1 | kirakira
# Processing Record 28 of Set 1 | el alto
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | kabare
# Processing Record 31 of Set 1 | la'ie
# Processing Record 32 of Set 1 | marsh harbour
# Processing Record 33 of Set 1 | ust-nera
# Processing Record 34 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | lhasa
# Processing Record 37 of Set 1 | whitehorse
# Processing Record 38 of Set 1 | xining
# Processing Record 39 of Set 1 | stanley
# Processing Record 40 of Set 1 | blackmans bay
# Processing Record 41 of Set 1 | margaret river
# Processing Record 42 of Set 1 | escanaba
# Processing Record 43 of Set 1 | waitangi
# Processing Record 44 of Set 1 | utrik
# Processing Record 45 of Set 1 | jisr ash shughur
# Processing Record 46 of Set 1 | ketchikan
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | oualidia
# City not found. Skipping...
# Processing Record 49 of Set 1 | el jadid
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 0 of Set 2 | revda
# Processing Record 1 of Set 2 | papatowai
# Processing Record 2 of Set 2 | porto torres
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | klyuchi
# Processing Record 5 of Set 2 | sinabang
# Processing Record 6 of Set 2 | san andres
# Processing Record 7 of Set 2 | yaren
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | masterton
# Processing Record 10 of Set 2 | kourou
# Processing Record 11 of Set 2 | weno
# Processing Record 12 of Set 2 | iskateley
# Processing Record 13 of Set 2 | kingston
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | luanco
# Processing Record 16 of Set 2 | anadyr
# Processing Record 17 of Set 2 | khorixas
# Processing Record 18 of Set 2 | bayanhongor
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | portland
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | coronel dorrego
# Processing Record 23 of Set 2 | alaghsas
# Processing Record 24 of Set 2 | maintirano
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | minas de marcona
# Processing Record 28 of Set 2 | itoman
# Processing Record 29 of Set 2 | wailua homesteads
# Processing Record 30 of Set 2 | hermiston
# Processing Record 31 of Set 2 | deqen
# Processing Record 32 of Set 2 | grytviken
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | regente feijo
# Processing Record 35 of Set 2 | thames
# Processing Record 36 of Set 2 | nouadhibou
# Processing Record 37 of Set 2 | la foa
# Processing Record 38 of Set 2 | kruisfontein
# Processing Record 39 of Set 2 | malango
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | kantang
# Processing Record 43 of Set 2 | ikryanoye
# Processing Record 44 of Set 2 | atafu village
# Processing Record 45 of Set 2 | malabar
# Processing Record 46 of Set 2 | vorgashor
# Processing Record 47 of Set 2 | namibe
# Processing Record 48 of Set 2 | vilyuchinsk
# Processing Record 49 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 0 of Set 3 | mikuni
# Processing Record 1 of Set 3 | acapulco de juarez
# Processing Record 2 of Set 3 | leava
# Processing Record 3 of Set 3 | shemgang
# Processing Record 4 of Set 3 | axim
# Processing Record 5 of Set 3 | shumikha
# Processing Record 6 of Set 3 | polyarnyy
# Processing Record 7 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 8 of Set 3 | amble
# Processing Record 9 of Set 3 | besskorbnaya
# Processing Record 10 of Set 3 | alvaraes
# Processing Record 11 of Set 3 | egersund
# Processing Record 12 of Set 3 | caribou
# Processing Record 13 of Set 3 | chonchi
# Processing Record 14 of Set 3 | argo
# Processing Record 15 of Set 3 | tolanaro
# Processing Record 16 of Set 3 | hawaiian paradise park
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | arawa
# Processing Record 20 of Set 3 | vorontsovka
# Processing Record 21 of Set 3 | kalmunai
# Processing Record 22 of Set 3 | noosa heads
# Processing Record 23 of Set 3 | northam
# Processing Record 24 of Set 3 | ishigaki
# Processing Record 25 of Set 3 | emerald
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | invercargill
# Processing Record 28 of Set 3 | thurso
# Processing Record 29 of Set 3 | banaz
# Processing Record 30 of Set 3 | udachny
# Processing Record 31 of Set 3 | choma
# Processing Record 32 of Set 3 | singleton
# Processing Record 33 of Set 3 | popilnia
# Processing Record 34 of Set 3 | filey
# Processing Record 35 of Set 3 | danielskuil
# Processing Record 36 of Set 3 | isafjordur
# Processing Record 37 of Set 3 | chieti
# Processing Record 38 of Set 3 | coquimbo
# Processing Record 39 of Set 3 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 40 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | mugia
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | barra do garcas
# Processing Record 45 of Set 3 | isla del bosque
# Processing Record 46 of Set 3 | hajduboszormeny
# Processing Record 47 of Set 3 | aljezur
# Processing Record 48 of Set 3 | kristiansund
# Processing Record 49 of Set 3 | pimentel
# Processing Record 0 of Set 4 | tamanrasset
# Processing Record 1 of Set 4 | berezovyy
# Processing Record 2 of Set 4 | nova vicosa
# Processing Record 3 of Set 4 | beyneu
# Processing Record 4 of Set 4 | al kharijah
# Processing Record 5 of Set 4 | dedza
# Processing Record 6 of Set 4 | kayangel
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | college
# Processing Record 9 of Set 4 | lesnoy
# Processing Record 10 of Set 4 | mhasvad
# Processing Record 11 of Set 4 | las tablas
# Processing Record 12 of Set 4 | saratamata
# City not found. Skipping...
# Processing Record 13 of Set 4 | suzemka
# Processing Record 14 of Set 4 | tazovsky
# Processing Record 15 of Set 4 | bixby
# Processing Record 16 of Set 4 | waingapu
# Processing Record 17 of Set 4 | qarshi
# Processing Record 18 of Set 4 | nemuro
# Processing Record 19 of Set 4 | puerto baquerizo moreno
# Processing Record 20 of Set 4 | port lincoln
# Processing Record 21 of Set 4 | gamay
# Processing Record 22 of Set 4 | thinadhoo
# Processing Record 23 of Set 4 | namsos
# Processing Record 24 of Set 4 | alesund
# Processing Record 25 of Set 4 | colonia menno
# Processing Record 26 of Set 4 | jennings
# Processing Record 27 of Set 4 | st. john's
# Processing Record 28 of Set 4 | gobabis
# Processing Record 29 of Set 4 | dhanwar
# Processing Record 30 of Set 4 | jamestown
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | tura
# Processing Record 33 of Set 4 | kamyshlov
# Processing Record 34 of Set 4 | ta`u
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | ola
# Processing Record 37 of Set 4 | kabompo
# Processing Record 38 of Set 4 | beruniy
# Processing Record 39 of Set 4 | ancud
# Processing Record 40 of Set 4 | friedland
# Processing Record 41 of Set 4 | sao tome
# Processing Record 42 of Set 4 | igarka
# Processing Record 43 of Set 4 | al bardiyah
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | susuman
# Processing Record 46 of Set 4 | shitanjing
# Processing Record 47 of Set 4 | beneditinos
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | almazan
# Processing Record 0 of Set 5 | garachico
# Processing Record 1 of Set 5 | talara
# Processing Record 2 of Set 5 | badger
# Processing Record 3 of Set 5 | viransehir
# Processing Record 4 of Set 5 | glace bay
# Processing Record 5 of Set 5 | trevelin
# Processing Record 6 of Set 5 | chernyshevskiy
# Processing Record 7 of Set 5 | alo
# Processing Record 8 of Set 5 | whitehaven
# Processing Record 9 of Set 5 | geraldton
# Processing Record 10 of Set 5 | big spring
# Processing Record 11 of Set 5 | nagqu
# Processing Record 12 of Set 5 | hinton
# Processing Record 13 of Set 5 | turinsk
# Processing Record 14 of Set 5 | aasiaat
# Processing Record 15 of Set 5 | bonthe
# Processing Record 16 of Set 5 | itaituba
# Processing Record 17 of Set 5 | acarau
# Processing Record 18 of Set 5 | dunedin
# Processing Record 19 of Set 5 | port mathurin
# Processing Record 20 of Set 5 | westport
# Processing Record 21 of Set 5 | la mira
# Processing Record 22 of Set 5 | ust'-uda
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | san antonio de pale
# Processing Record 25 of Set 5 | sangkhla buri
# Processing Record 26 of Set 5 | mari-turek
# Processing Record 27 of Set 5 | san patricio
# Processing Record 28 of Set 5 | kudahuvadhoo
# Processing Record 29 of Set 5 | sibsagar
# Processing Record 30 of Set 5 | samara
# Processing Record 31 of Set 5 | gilgit
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | carutapera
# Processing Record 34 of Set 5 | badiyah
# Processing Record 35 of Set 5 | yemetsk
# Processing Record 36 of Set 5 | magadan
# Processing Record 37 of Set 5 | velikiye luki
# Processing Record 38 of Set 5 | abdulino
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | saurimo
# Processing Record 41 of Set 5 | dickinson
# Processing Record 42 of Set 5 | at-bashi
# Processing Record 43 of Set 5 | fort st. john
# Processing Record 44 of Set 5 | nar'yan-mar
# Processing Record 45 of Set 5 | dogonbadan
# Processing Record 46 of Set 5 | eydhafushi
# Processing Record 47 of Set 5 | borodino
# Processing Record 48 of Set 5 | mount gambier
# Processing Record 49 of Set 5 | tyup
# Processing Record 0 of Set 6 | labrador city
# Processing Record 1 of Set 6 | chyorny yar
# Processing Record 2 of Set 6 | palmer
# Processing Record 3 of Set 6 | bereeda
# Processing Record 4 of Set 6 | mo i rana
# Processing Record 5 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 6 | san luis
# Processing Record 7 of Set 6 | jiagedaqi
# Processing Record 8 of Set 6 | saldanha
# Processing Record 9 of Set 6 | puerto lempira
# Processing Record 10 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 11 of Set 6 | sanchor
# Processing Record 12 of Set 6 | los llanos de aridane
# Processing Record 13 of Set 6 | isangel
# Processing Record 14 of Set 6 | jackson
# Processing Record 15 of Set 6 | ulladulla
# Processing Record 16 of Set 6 | melfort
# Processing Record 17 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 6 | simanggang
# Processing Record 19 of Set 6 | ladismith
# City not found. Skipping...
# Processing Record 20 of Set 6 | tuburan
# Processing Record 21 of Set 6 | sola
# Processing Record 22 of Set 6 | tabuk
# Processing Record 23 of Set 6 | guerrero negro
# Processing Record 24 of Set 6 | cabedelo
# Processing Record 25 of Set 6 | bontang
# Processing Record 26 of Set 6 | arys
# Processing Record 27 of Set 6 | mont-dore
# Processing Record 28 of Set 6 | loyew
# Processing Record 29 of Set 6 | dudinka
# Processing Record 30 of Set 6 | soe
# Processing Record 31 of Set 6 | olinda
# Processing Record 32 of Set 6 | matthew town
# Processing Record 33 of Set 6 | lengshuitan
# Processing Record 34 of Set 6 | bom jesus do galho
# Processing Record 35 of Set 6 | jalai nur
# Processing Record 36 of Set 6 | lihue
# Processing Record 37 of Set 6 | arvayheer
# Processing Record 38 of Set 6 | totness
# Processing Record 39 of Set 6 | yuzhno-kurilsk
# Processing Record 40 of Set 6 | akureyri
# Processing Record 41 of Set 6 | sao gabriel da cachoeira
# Processing Record 42 of Set 6 | santa cruz
# Processing Record 43 of Set 6 | luderitz
# Processing Record 44 of Set 6 | kamloops
# Processing Record 45 of Set 6 | ciudad bolivar
# Processing Record 46 of Set 6 | mahibadhoo
# Processing Record 47 of Set 6 | abepura
# Processing Record 48 of Set 6 | wabag
# Processing Record 49 of Set 6 | izyaslav
# Processing Record 0 of Set 7 | happy valley-goose bay
# Processing Record 1 of Set 7 | saipan
# Processing Record 2 of Set 7 | adrar
# Processing Record 3 of Set 7 | makary
# Processing Record 4 of Set 7 | camrose
# Processing Record 5 of Set 7 | pangody
# Processing Record 6 of Set 7 | altay
# Processing Record 7 of Set 7 | montecristo
# Processing Record 8 of Set 7 | tazacorte
# Processing Record 9 of Set 7 | tisul'
# Processing Record 10 of Set 7 | usogorsk
# Processing Record 11 of Set 7 | margherita
# Processing Record 12 of Set 7 | warri
# Processing Record 13 of Set 7 | mary
# Processing Record 14 of Set 7 | shingu
# Processing Record 15 of Set 7 | mazabuka
# Processing Record 16 of Set 7 | wokha
# Processing Record 17 of Set 7 | lerwick
# Processing Record 18 of Set 7 | ventspils
# Processing Record 19 of Set 7 | kavaratti
# Processing Record 20 of Set 7 | selfoss
# Processing Record 21 of Set 7 | mweka
# Processing Record 22 of Set 7 | fort mcmurray
# Processing Record 23 of Set 7 | uliastay
# Processing Record 24 of Set 7 | jaca
# Processing Record 25 of Set 7 | murzuq
# Processing Record 26 of Set 7 | broome
# Processing Record 27 of Set 7 | la passe
# Processing Record 28 of Set 7 | mariehamn
# Processing Record 29 of Set 7 | gushu
# Processing Record 30 of Set 7 | gondia
# Processing Record 31 of Set 7 | mili
# Processing Record 32 of Set 7 | rio grande
# Processing Record 33 of Set 7 | richards bay
# Processing Record 34 of Set 7 | tadine
# Processing Record 35 of Set 7 | lorengau
# Processing Record 36 of Set 7 | terme
# Processing Record 37 of Set 7 | rongelap
# Processing Record 38 of Set 7 | yantongshan
# Processing Record 39 of Set 7 | miramichi
# Processing Record 40 of Set 7 | betio village
# Processing Record 41 of Set 7 | hamilton
# Processing Record 42 of Set 7 | hoemul-li
# Processing Record 43 of Set 7 | sandnessjoen
# Processing Record 44 of Set 7 | ploudalmezeau
# Processing Record 45 of Set 7 | elliot
# Processing Record 46 of Set 7 | gisborne
# Processing Record 47 of Set 7 | aegina
# Processing Record 48 of Set 7 | el granada
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 0 of Set 8 | oeiras do para
# Processing Record 1 of Set 8 | newman
# Processing Record 2 of Set 8 | nieuw amsterdam
# Processing Record 3 of Set 8 | coahuayana de hidalgo
# Processing Record 4 of Set 8 | khvansar
# Processing Record 5 of Set 8 | lalian
# Processing Record 6 of Set 8 | truro
# Processing Record 7 of Set 8 | guercif
# Processing Record 8 of Set 8 | isle of lewis
# City not found. Skipping...
# Processing Record 9 of Set 8 | cockburn town
# Processing Record 10 of Set 8 | al bawiti
# Processing Record 11 of Set 8 | enewetak
# Processing Record 12 of Set 8 | flying fish cove
# Processing Record 13 of Set 8 | bellefonte
# Processing Record 14 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 15 of Set 8 | mirny
# Processing Record 16 of Set 8 | porbandar
# Processing Record 17 of Set 8 | yanchep
# Processing Record 18 of Set 8 | quellon
# Processing Record 19 of Set 8 | vrangel'
# Processing Record 20 of Set 8 | kapa'a
# Processing Record 21 of Set 8 | dinguiraye
# Processing Record 22 of Set 8 | afua
# Processing Record 23 of Set 8 | beldanga
# Processing Record 24 of Set 8 | tatabanya
# Processing Record 25 of Set 8 | dwarka
# Processing Record 26 of Set 8 | keflavik
# Processing Record 27 of Set 8 | guatrache
# Processing Record 28 of Set 8 | maceio
# Processing Record 29 of Set 8 | qaqortoq
# Processing Record 30 of Set 8 | port shepstone
# Processing Record 31 of Set 8 | hami
# Processing Record 32 of Set 8 | mareeba
# Processing Record 33 of Set 8 | praia da vitoria
# Processing Record 34 of Set 8 | badarwas
# Processing Record 35 of Set 8 | gamba
# Processing Record 36 of Set 8 | yerba buena
# Processing Record 37 of Set 8 | conduaga
# Processing Record 38 of Set 8 | aiquile
# Processing Record 39 of Set 8 | fort bragg
# Processing Record 40 of Set 8 | gadzhiyevo
# Processing Record 41 of Set 8 | sterling
# Processing Record 42 of Set 8 | boguchany
# Processing Record 43 of Set 8 | aykhal
# Processing Record 44 of Set 8 | turkmenabat
# Processing Record 45 of Set 8 | zemio
# Processing Record 46 of Set 8 | wenling
# Processing Record 47 of Set 8 | guilin
# Processing Record 48 of Set 8 | cottage grove
# Processing Record 49 of Set 8 | gorontalo
# Processing Record 0 of Set 9 | margate
# Processing Record 1 of Set 9 | nabire
# Processing Record 2 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 3 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 4 of Set 9 | saint-joseph
# Processing Record 5 of Set 9 | sausset-les-pins
# Processing Record 6 of Set 9 | nukunonu
# City not found. Skipping...
# Processing Record 7 of Set 9 | odda
# Processing Record 8 of Set 9 | kuanda
# Processing Record 9 of Set 9 | perieni
# Processing Record 10 of Set 9 | saint-pierre
# Processing Record 11 of Set 9 | mejit
# Processing Record 12 of Set 9 | colonia
# Processing Record 13 of Set 9 | laguna
# Processing Record 14 of Set 9 | port saint john's
# Processing Record 15 of Set 9 | george town
# Processing Record 16 of Set 9 | valparaiso
# Processing Record 17 of Set 9 | togur
# Processing Record 18 of Set 9 | nadi
# Processing Record 19 of Set 9 | pandan
# Processing Record 20 of Set 9 | antsiranana
# Processing Record 21 of Set 9 | svetlyy
# Processing Record 22 of Set 9 | oneonta
# Processing Record 23 of Set 9 | shangri-la
# City not found. Skipping...
# Processing Record 24 of Set 9 | coyhaique
# Processing Record 25 of Set 9 | nova sintra
# Processing Record 26 of Set 9 | smithers
# Processing Record 27 of Set 9 | cabinda
# Processing Record 28 of Set 9 | halifax
# Processing Record 29 of Set 9 | tionk essil
# Processing Record 30 of Set 9 | levuka
# Processing Record 31 of Set 9 | uturoa
# Processing Record 32 of Set 9 | christchurch
# Processing Record 33 of Set 9 | ko pha ngan
# Processing Record 34 of Set 9 | ocos
# Processing Record 35 of Set 9 | lukolela
# Processing Record 36 of Set 9 | midvagur
# Processing Record 37 of Set 9 | talcahuano
# Processing Record 38 of Set 9 | dadukou
# Processing Record 39 of Set 9 | prince rupert
# Processing Record 40 of Set 9 | solnechnyy
# Processing Record 41 of Set 9 | lethem
# Processing Record 42 of Set 9 | salalah
# Processing Record 43 of Set 9 | sinop
# Processing Record 44 of Set 9 | tobruk
# Processing Record 45 of Set 9 | mato verde
# Processing Record 46 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 9 | santa maria del oro
# Processing Record 48 of Set 9 | misratah
# Processing Record 49 of Set 9 | perelyub
# Processing Record 0 of Set 10 | krasnyy chikoy
# Processing Record 1 of Set 10 | narvik
# Processing Record 2 of Set 10 | puerto aysen
# Processing Record 3 of Set 10 | sorong
# Processing Record 4 of Set 10 | lodja
# Processing Record 5 of Set 10 | taoudenni
# Processing Record 6 of Set 10 | lata
# Processing Record 7 of Set 10 | la ronge
# Processing Record 8 of Set 10 | dolbeau-mistassini
# Processing Record 9 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 10 of Set 10 | tongouson
# Processing Record 11 of Set 10 | ghat
# Processing Record 12 of Set 10 | nishinoomote
# Processing Record 13 of Set 10 | horta
# Processing Record 14 of Set 10 | kiunga
# Processing Record 15 of Set 10 | ghadamis
# Processing Record 16 of Set 10 | vernon
# Processing Record 17 of Set 10 | dem'yanovo
# Processing Record 18 of Set 10 | chipinge
# Processing Record 19 of Set 10 | chhindwara
# Processing Record 20 of Set 10 | dryden
# Processing Record 21 of Set 10 | potam
# Processing Record 22 of Set 10 | cole harbour
# Processing Record 23 of Set 10 | pasuquin
# Processing Record 24 of Set 10 | sant lluis
# Processing Record 25 of Set 10 | keelung
# Processing Record 26 of Set 10 | la jolla
# Processing Record 27 of Set 10 | agua prieta
# Processing Record 28 of Set 10 | ciudad guayana
# Processing Record 29 of Set 10 | mayahi
# Processing Record 30 of Set 10 | cody
# Processing Record 31 of Set 10 | howard springs
# Processing Record 32 of Set 10 | vanino
# Processing Record 33 of Set 10 | kimbe
# Processing Record 34 of Set 10 | amga
# Processing Record 35 of Set 10 | val-d'or
# Processing Record 36 of Set 10 | hassi messaoud
# Processing Record 37 of Set 10 | vorkuta
# Processing Record 38 of Set 10 | al-`ula
# City not found. Skipping...
# Processing Record 39 of Set 10 | zangguy
# City not found. Skipping...
# Processing Record 40 of Set 10 | nampula
# Processing Record 41 of Set 10 | antalaha
# Processing Record 42 of Set 10 | yaransk
# Processing Record 43 of Set 10 | karasburg
# Processing Record 44 of Set 10 | sagalo
# City not found. Skipping...
# Processing Record 45 of Set 10 | kailua-kona
# Processing Record 46 of Set 10 | shevchenko
# Processing Record 47 of Set 10 | lompoc
# Processing Record 48 of Set 10 | tsiombe
# Processing Record 49 of Set 10 | iwanai
# Processing Record 0 of Set 11 | mildura
# Processing Record 1 of Set 11 | brodnica
# Processing Record 2 of Set 11 | fairmont
# Processing Record 3 of Set 11 | bathsheba
# Processing Record 4 of Set 11 | afaahiti
# Processing Record 5 of Set 11 | rio gallegos
# Processing Record 6 of Set 11 | tambura
# Processing Record 7 of Set 11 | anibare
# City not found. Skipping...
# Processing Record 8 of Set 11 | kicevo
# Processing Record 9 of Set 11 | miguel ahumada
# Processing Record 10 of Set 11 | mongoumba
# Processing Record 11 of Set 11 | neuzeug
# Processing Record 12 of Set 11 | ruston
# Processing Record 13 of Set 11 | megion
# Processing Record 14 of Set 11 | musoma
# Processing Record 15 of Set 11 | prado
# Processing Record 16 of Set 11 | corfu
# Processing Record 17 of Set 11 | olyokminsk
# Processing Record 18 of Set 11 | auki
# Processing Record 19 of Set 11 | goroka
# Processing Record 20 of Set 11 | ayod
# City not found. Skipping...
# Processing Record 21 of Set 11 | yichang
# Processing Record 22 of Set 11 | kwang binh
# Processing Record 23 of Set 11 | mimizan
# Processing Record 24 of Set 11 | sitampiky
# City not found. Skipping...
# Processing Record 25 of Set 11 | ivanteyevka
# Processing Record 26 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 27 of Set 11 | moya
# Processing Record 28 of Set 11 | sharan
# Processing Record 29 of Set 11 | usinsk
# Processing Record 30 of Set 11 | yamada
# Processing Record 31 of Set 11 | queenstown
# Processing Record 32 of Set 11 | buka
# Processing Record 33 of Set 11 | chake chake
# Processing Record 34 of Set 11 | bou ismail
# Processing Record 35 of Set 11 | kaoma
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | mexico
# Processing Record 38 of Set 11 | wuyang
# Processing Record 39 of Set 11 | bucerias
# Processing Record 40 of Set 11 | waddan
# Processing Record 41 of Set 11 | lycksele
# Processing Record 42 of Set 11 | quepos
# Processing Record 43 of Set 11 | tofol
# Processing Record 44 of Set 11 | kulhudhuffushi
# Processing Record 45 of Set 11 | malvan
# Processing Record 46 of Set 11 | renk
# City not found. Skipping...
# Processing Record 47 of Set 11 | tiassale
# Processing Record 48 of Set 11 | egilsstadir
# Processing Record 49 of Set 11 | hluti
# Processing Record 0 of Set 12 | savanna-la-mar
# Processing Record 1 of Set 12 | cefalu
# Processing Record 2 of Set 12 | new norfolk
# Processing Record 3 of Set 12 | porto belo
# Processing Record 4 of Set 12 | beroroha
# Processing Record 5 of Set 12 | gebeit
# Processing Record 6 of Set 12 | rock springs
# Processing Record 7 of Set 12 | fale old settlement
# Processing Record 8 of Set 12 | visakhapatnam
# Processing Record 9 of Set 12 | quang ngai
# Processing Record 10 of Set 12 | vilyuysk
# Processing Record 11 of Set 12 | huarmey
# Processing Record 12 of Set 12 | masindi port
# Processing Record 13 of Set 12 | monte caseros
# Processing Record 14 of Set 12 | ambon
# Processing Record 15 of Set 12 | kill devil hills
# Processing Record 16 of Set 12 | brandon
# Processing Record 17 of Set 12 | general acha
# Processing Record 18 of Set 12 | arno
# Processing Record 19 of Set 12 | bamboo flat
# Processing Record 20 of Set 12 | khilok
# Processing Record 21 of Set 12 | crane
# Processing Record 22 of Set 12 | arkalyk
# Processing Record 23 of Set 12 | soio
# Processing Record 24 of Set 12 | oriximina
# Processing Record 25 of Set 12 | trairi
# Processing Record 26 of Set 12 | pointe-noire
# Processing Record 27 of Set 12 | ballina
# Processing Record 28 of Set 12 | nizhnyaya tavda
# Processing Record 29 of Set 12 | mach
# Processing Record 30 of Set 12 | altamont
# Processing Record 31 of Set 12 | roquetas de mar
# Processing Record 32 of Set 12 | ha'il
# Processing Record 33 of Set 12 | rio branco do sul
# Processing Record 34 of Set 12 | salekhard
# Processing Record 35 of Set 12 | abnub
# Processing Record 36 of Set 12 | tha yang
# Processing Record 37 of Set 12 | allapalli
# Processing Record 38 of Set 12 | macusani
# Processing Record 39 of Set 12 | karratha
# Processing Record 40 of Set 12 | essaouira
# Processing Record 41 of Set 12 | awjilah
# Processing Record 42 of Set 12 | vadso
# Processing Record 43 of Set 12 | constitucion
# Processing Record 44 of Set 12 | sur
# Processing Record 45 of Set 12 | carnot
# Processing Record 46 of Set 12 | sakaiminato
# Processing Record 47 of Set 12 | galle
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          port alfred -33.5906  26.8910     14.54        72          64
# 1  san marcos de colon  13.4333 -86.8000     20.01        93          96
# 2               cuamba -14.8031  36.5372     13.21        70           0
# 3                  leh  34.1667  77.5833     12.62        43          83
# 4           constantia  44.1833  28.6500     16.50        83          72
#
#    Wind Speed Country        Date
# 0        2.68      ZA  1686542091
# 1        0.80      HN  1686542091
# 2        0.37      MZ  1686542091
# 3        1.06      IN  1686542091
# 4        8.90      RO  1686542091

# %%
# Export the City_Data into a csv
if not os.path.exists('output_data'):
    os.makedirs('output_data')
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                port alfred -33.5906  26.8910     14.54        72
# 1        san marcos de colon  13.4333 -86.8000     20.01        93
# 2                     cuamba -14.8031  36.5372     13.21        70
# 3                        leh  34.1667  77.5833     12.62        43
# 4                 constantia  44.1833  28.6500     16.50        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                64        2.68      ZA  1686542091
# 1                96        0.80      HN  1686542091
# 2                 0        0.37      MZ  1686542091
# 3                83        1.06      IN  1686542091
# 4                72        8.90      RO  1686542091

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", label="Cities")

# Incorporate the other graph properties

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", label="Cities")
# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o",label="Cities")
# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
from scipy.stats import linregress

def plot_regression(x, y, title, ylabs, coor):
    # calc regression
    (slope, intercept, r_value, _, _) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    #scatter plot and regression line
    plt.scatter(x, y)
    plt.plot(x, regress_values, "r-")
    plt.text(text_position[0], text_position[1], line_eq, fontsize=12, color="red", transform=plt.gca().transAxes)
    plt.ylabel(ylabs)
    plt.xlabel('Latitude')
    plt.title(title)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1        san marcos de colon  13.4333  -86.8000     20.01        93
# 3                        leh  34.1667   77.5833     12.62        43
# 4                 constantia  44.1833   28.6500     16.50        83
# 7                      tokar  18.4254   37.7290     32.36        51
# 8                    okhotsk  59.3833  143.3000     12.28        75
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                96        0.80      HN  1686542091
# 3                83        1.06      IN  1686542091
# 4                72        8.90      RO  1686542091
# 7                19        3.79      SD  1686542091
# 8                45        4.26      RU  1686542091

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                        port alfred -33.5906   26.8910     14.54        72
# 2                             cuamba -14.8031   36.5372     13.21        70
# 5                     puerto natales -51.7236  -72.4875      3.84        87
# 6        edinburgh of the seven seas -37.0676  -12.3116     16.04        89
# 10                        codrington -38.2667  141.9667     15.66        60
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                64        2.68      ZA  1686542091
# 2                 0        0.37      MZ  1686542091
# 5                55        5.94      CL  1686542091
# 6                88       13.80      SH  1686542076
# 10               17        7.82      AU  1686542091

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Max Temp"]
title = 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature'
ylabs = 'Max Temp'
text_position = (0.6, 0.95)

# Call the function
plot_regression(x_val, y_val, title, ylabs, coor)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_values, y_values)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.5739957534848704

# %%
# Linear regression on Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Max Temp"]
title = 'Linear Regression on the Southern Hemisphere \n for Maximum Temperature'
ylabs = 'Max Temp'
text_position = (0.1, 0.9) 

# Call the function
plot_regression(x_val, y_val, title, ylabs, text_position)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_val, y_val)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.5450761564026888

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In the Northern Hemisphere, there is a moderate negative relationship between latitude and temperature, as depicted by the linear regression equation y = -0.33x + 32.83, with an R-squared value of 0.574. This suggests that as one moves further from the equator, the temperature tends to decrease; specifically, for each unit increase in latitude, the temperature decreases by 0.33 units. Conversely, in the Southern Hemisphere, the relationship between latitude and temperature is moderately positive, with a linear regression equation of y = 0.42x + 26.82 and an R-squared value of 0.545. This indicates that as one moves closer to the equator in the Southern Hemisphere, the temperature tends to increase by 0.42 units for each unit increase in latitude. In summary, temperatures are influenced by latitude in both hemispheres, but in opposite directions: in the Northern Hemisphere, temperatures decrease with increasing latitude, while in the Southern Hemisphere, they increase as one approaches the equator. The regression models capture these geographically intuitive trends effectively.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Humidity"]
ylabs = '% Humidity'
text_position = (0.7, 0.1) 
title = 'Regression Northern Hemisphere for Humidity'


# Call the function
plot_regression(x_val, y_val, title, ylabs, text_position)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_val, y_val)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.016877218382410773

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Humidity"]
title = 'Regression Southern Hemisphere for Humidity'
ylabs = '% Humidity'
text_position = (0.1, 0.2) # Adjusting the relative position here

# Call the function
plot_regression(x_val, y_val, title, ylabs, text_position)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_val, y_val)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.031783398157394074

# %% [markdown]
# **Discussion about the linear relationship:**
#
#
# In the Northern Hemisphere, the relationship between latitude and humidity is very weak, as indicated by the linear regression equation y = -0.15x + 73.3, with an R-squared value of only 0.017. This suggests that latitude has minimal impact on humidity levels in the Northern Hemisphere. Essentially, there is a very slight tendency for humidity to decrease as one moves further from the equator, but the effect is not pronounced. On the other hand, in the Southern Hemisphere, the relationship between latitude and humidity is also weak but slightly positive, with a linear regression equation of y = 0.22x + 77.78 and an R-squared value of 0.032. This indicates a marginal increase in humidity levels as one moves closer to the equator in the Southern Hemisphere. However, similar to the Northern Hemisphere, the effect is very subtle. In summary, humidity levels do not seem to be strongly influenced by latitude in either hemisphere, and other factors likely play a more significant role in determining humidity levels in different regions.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Cloudiness"]
title = 'Regression on Northern Hemisphere for Cloudiness'
ylabs = '% Cloudiness'
text_position = (0.7, 0.3) # Adjusting the relative position here

# Call the function
plot_regression(x_val, y_val, title, ylabs, text_position)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_val, y_val)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.0037119874487394223

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Cloudiness"]
title = 'Regression on Southern Hemisphere for Cloudiness'
ylabs = '% Cloudiness'
text_position = (0.1, 0.2) # Adjusting the relative position here

# Call the function
plot_regression(x_val, y_val, title, ylabs, text_position)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_val, y_val)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.01726140591027835

# %% [markdown]
# **Discussion about the linear relationship:**
#
#
#
# In the Northern Hemisphere, the relationship between latitude and cloudiness is very weak, as evidenced by the linear regression equation y = -0.13x + 63.2 and an R-squared value of 0.0037. This indicates that there is hardly any correlation between latitude and cloudiness in the Northern Hemisphere, and the slight negative slope suggests that cloudiness marginally decreases as one moves away from the equator, but this is not statistically significant. Similarly, in the Southern Hemisphere, the correlation between latitude and cloudiness is also very weak, as indicated by the equation y = 0.35x + 53.36 and an R-squared value of 0.0173. However, in contrast to the Northern Hemisphere, the Southern Hemisphere shows a slight positive correlation, indicating that cloudiness may increase marginally as one moves closer to the equator. The overall analysis suggests that latitude does not have a significant impact on cloudiness in either hemisphere, and cloudiness levels are likely to be influenced by other factors such as atmospheric conditions, geography, and seasonal variations.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Wind Speed"]
title = 'Regression on Northern Hemisphere for Wind Speed'
ylabs = 'Wind Speed'
text_position = (0.1, 0.8)
# Call the function
plot_regression(x_val, y_val, title, ylabs, text_position)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_val, y_val)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.002991210706102294

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Wind Speed"]
title = 'Regression on Northern Hemisphere for Wind Speed'
ylabs = 'Wind Speed'
text_position = (0.1, 0.8)
# Call the function
plot_regression(x_val, y_val, title, ylabs, text_position)

# Print the r-value
(slope, intercept, r_value, _, _) = linregress(x_val, y_val)
print(f"The r-value is: {r_value**2}")
# Out:
# The r-value is: 0.06292638811239948

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In the Northern Hemisphere, the linear regression between latitude and wind speed is represented by the equation y = 0.01x + 3.51, with an R-squared value of 0.003. This extremely low R-squared value indicates that there is essentially no correlation between latitude and wind speed in the Northern Hemisphere. The positive slope of the line is very shallow, implying that even if there is a relationship, it is very weak.
# In the Southern Hemisphere, the linear regression equation is y = -0.05x + 2.68, with an R-squared value of 0.0629. This R-squared value is slightly higher than that of the Northern Hemisphere but still indicates a weak correlation. The negative slope suggests a mild decrease in wind speed as one moves closer to the equator.
# In conclusion, both the Northern and Southern Hemispheres do not show a significant correlation between latitude and wind speed. This suggests that wind speed is likely influenced by other factors such as geographic features, atmospheric pressure systems, and local weather patterns, rather than latitude alone.
